# %%
vocab = list(model.wv.vocab) 
X = model[vocab]
len(X)
# Out:
# /home/guiraiol/anaconda3/envs/idp/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# 3700

# %%
import math
grid = 20

# %%
pl.imshow(som.K[:,:,0], origin='lower')

# %%
pl.figure(figsize=(80,80))
pl.imshow(som.K[:,:,0], origin='lower')
pl.colorbar()
for i in range(0,31):
    for j in range(0,31):
        #print(i,j, )
        pl.text(i, j, M[i][j][0], ha='center', va='center', bbox=dict(facecolor='white', alpha=0.5, lw=0))
